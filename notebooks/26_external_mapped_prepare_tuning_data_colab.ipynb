# %% [markdown]
# # 26 - Prepare External-Mapped Tuning Data
#
# Maps external legal examples to the official-law `doc_key`, `article_key`, and `citation_label` schema without using the locked final benchmark for training.

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
PROJECT_DIR = '/content/drive/MyDrive/rag'
os.chdir(PROJECT_DIR)
print(os.getcwd())

# %%
# !pip install -r requirements.txt

# %%
# !python -m src.prepare_external_mapped_tuning_data \
  --corpus-csv data/processed/legal_main_law_corpus_v3.csv \
  --external-dir data/external \
  --output-dir data/processed \
  --report-path reports/external_mapped_tuning_data_report.json

# %% [markdown]
# Generated files:
#
# - `data/processed/external_mapped_embedding_train.jsonl`
# - `data/processed/external_mapped_embedding_val.jsonl`
# - `data/processed/external_mapped_reranker_train.jsonl`
# - `data/processed/external_mapped_reranker_val.jsonl`
# - `data/processed/external_mapped_llm_train.jsonl`
# - `data/processed/external_mapped_llm_val.jsonl`
# - `reports/external_mapped_tuning_data_report.json`
